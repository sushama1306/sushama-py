# %%
print("sushama")
# Out:
# sushama

# %%
n=int(input("enter the number"))
res=n*n
print(" the square of the number is",res)
# Out:
# enter the number 42
#  the square of the number is 1764

# %%
n=int(input("Enter the age of user"))
print("age of the user is",n)
# Out:
# Enter the age of user 20
# age of the user is 20

# %% [markdown]
# #program for adddition of two numbers

# %%
a=int(input("Enter the first number"))
b=int(input("Enter the second number"))
add=a+b
print("Addition of two number is",add)
# Out:
# Enter the first number 42
# Enter the second number 50
# Addition of two number is 92

# %% [markdown]
# #program to calculate average of 5 numbers

# %%
a=int(input("Enter the first number"))
b=int(input("Entner the second number"))
c=int(input("Enter the third number"))
d=int(input("Enter the fourth number"))
e=int(input("Enter the fifth number"))
average=a+b+c+d+e/5
print("Addition of five number is",average)
# Out:
# Enter the first number 5
# Entner the second number 6
# Enter the third number 9
# Enter the fourth number 8
# Enter the fifth number 7
# Addition of five number is 29.4

# %% [markdown]
# #program to calculate area of triangle

# %%
a=int(input("enter height of triangle"))
b=int(input("enter base of triange"))
y=0.5 * a * b
print("calculate the area of triangle",y)
# Out:
# enter height of triangle 25
# enter base of triange 20
# calculate the area of triangle 250.0

# %% [markdown]
# #Pogram to calculate percentage

# %%
x=int(input("Enter the marks"))
y=int(input("Enter the gain marks"))
percentage=(y/x)*100
print("calculate the percentage",percentage)
# Out:
# Enter the marks 90
# Enter the gain marks 85
# calculate the percentage 94.44444444444444

# %% [markdown]
# #Area of circle

# %%
r=int(input("enter the radius"))
cir=3.14 * r *r
print("area of circle is",cir)
# Out:
# enter the radius 42
# area of circle is 5538.96
